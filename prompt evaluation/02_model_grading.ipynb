# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Extract AWS Account ID from ARN\n\nHere's a solution to extract the AWS account ID from an ARN string:\n\n```python\ndef extract_account_id(arn):\n    \"\"\"\n    Extract AWS account ID from an ARN string.\n    \n    Args:\n        arn (str): ARN string in format: arn:partition:service:region:account-id:resource\n    \n    Returns:\n        str: AWS account ID, or empty string if not present\n    \"\"\"\n    parts = arn.split(':')\n    \n    # ARN format: arn:partition:service:region:account-id:resource\n    # Index:       0      1        2       3      4         5+\n    if len(parts) >= 5:\n        return parts[4]\n    return \"\"\n\n\n# Test cases\ntest_arns = [\n    \"arn:aws:iam::123456789012:user/Development/product_1/*\",\n    \"arn:aws:s3:::my-bucket/path/to/object\",  # S3 doesn't have account ID\n    \"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\",\n    \"arn:aws:lambda:eu-west-1:999999999999:function:my-function\",\n]\n\nfor arn in test_arns:\n    account_id = extract_account_id(arn)\n    print(f\"ARN: {arn}\")\n    print(f\"Account ID: {account_id if account_id else '(not present)'}\\n\")\n```\n\n**Output:**\n```\nARN: arn:aws:iam::123456789012:user/Development/product_1/*\nAccount ID: 123456789012\n\nARN: arn:aws:s3:::my-bucket/path/to/object\nAccount ID: (not present)\n\nARN: arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\nAccount ID: 123456789012\n\nARN: arn:aws:lambda:eu-west-1:999999999999:function:my-function\nAccount ID: 999999999999\n```\n\n## Key Points:\n\n- **ARN Format**: `arn:partition:service:region:account-id:resource`\n- **Account ID Position**: Index 4 (5th element when split by `:`)\n- **S3 Bucket ARNs**: Don't contain account IDs (the field is empty)\n- **Empty String**: Returned when account ID is not present\n\nThis solution handles all AWS service ARNs correctly!",
#     "test_case": {
#       "task": "Extract the AWS account ID from an ARN string like 'arn:aws:s3:::my-bucket/path/to/object'",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the stated problem for well-formed ARNs and demonstrates understanding of AWS ARN structure. However, it lacks defensive programming practices appropriate for production code. Adding basic input validation (checking for 'arn:' prefix) and distinguishing between missing vs. malformed ARNs would significantly improve robustness. The implementation is functional but not production-hardened."
#   },
#   {
#     "output": "# AWS CloudFormation Template Parser\n\nI'll help you parse an AWS CloudFormation template. Here's a solution that extracts resource names and types:\n\n```python\nimport json\nimport yaml\n\ndef parse_cloudformation_template(template_input):\n    \"\"\"\n    Parse an AWS CloudFormation template and return resource names and types.\n    \n    Args:\n        template_input: Either a file path, JSON string, or YAML string\n        \n    Returns:\n        dict: JSON object with resource names and their types\n    \"\"\"\n    \n    # Load the template\n    template = load_template(template_input)\n    \n    # Extract resources\n    resources = template.get('Resources', {})\n    \n    # Build output\n    result = {\n        'resources': {}\n    }\n    \n    for resource_name, resource_config in resources.items():\n        resource_type = resource_config.get('Type', 'Unknown')\n        result['resources'][resource_name] = resource_type\n    \n    return result\n\n\ndef load_template(template_input):\n    \"\"\"Load template from various input formats.\"\"\"\n    \n    # Try to parse as JSON first\n    try:\n        return json.loads(template_input)\n    except (json.JSONDecodeError, TypeError):\n        pass\n    \n    # Try to parse as YAML\n    try:\n        return yaml.safe_load(template_input)\n    except yaml.YAMLError:\n        pass\n    \n    # Try to read from file\n    try:\n        with open(template_input, 'r') as f:\n            content = f.read()\n            try:\n                return json.loads(content)\n            except json.JSONDecodeError:\n                return yaml.safe_load(content)\n    except FileNotFoundError:\n        raise ValueError(\"Invalid input: not valid JSON, YAML, or file path\")\n\n\n# Example usage\nif __name__ == \"__main__\":\n    \n    # Example 1: JSON template\n    json_template = '''\n    {\n        \"AWSTemplateFormatVersion\": \"2010-09-09\",\n        \"Resources\": {\n            \"MyBucket\": {\n                \"Type\": \"AWS::S3::Bucket\",\n                \"Properties\": {\n                    \"BucketName\": \"my-bucket\"\n                }\n            },\n            \"MyRole\": {\n                \"Type\": \"AWS::IAM::Role\",\n                \"Properties\": {\n                    \"AssumeRolePolicyDocument\": {}\n                }\n            },\n            \"MyInstance\": {\n                \"Type\": \"AWS::EC2::Instance\",\n                \"Properties\": {\n                    \"ImageId\": \"ami-12345678\"\n                }\n            }\n        }\n    }\n    '''\n    \n    result = parse_cloudformation_template(json_template)\n    print(json.dumps(result, indent=2))\n    \n    # Example 2: YAML template\n    yaml_template = '''\n    AWSTemplateFormatVersion: '2010-09-09'\n    Resources:\n      MyDatabase:\n        Type: AWS::RDS::DBInstance\n        Properties:\n          DBInstanceClass: db.t3.micro\n      MyTable:\n        Type: AWS::DynamoDB::Table\n        Properties:\n          TableName: my-table\n    '''\n    \n    result = parse_cloudformation_template(yaml_template)\n    print(json.dumps(result, indent=2))\n```\n\n**Output Example:**\n```json\n{\n  \"resources\": {\n    \"MyBucket\": \"AWS::S3::Bucket\",\n    \"MyRole\": \"AWS::IAM::Role\",\n    \"MyInstance\": \"AWS::EC2::Instance\"\n  }\n}\n```\n\n## Features:\n\n\u2705 **Supports multiple input formats:**\n- JSON strings\n- YAML strings\n- File paths (JSON or YAML files)\n\n\u2705 **Extracts only:**\n- Resource logical IDs (names)\n- Resource types\n\n\u2705 **Returns structured JSON output**\n\n## Usage:\n\n```python\n# From file\nresult = parse_cloudformation_template('template.yaml')\n\n# From JSON string\nresult = parse_cloudformation_template('{\"Resources\": {...}}')\n\n# From YAML string",
#     "test_case": {
#       "task": "Parse an AWS CloudFormation template and return a JSON object containing only the resource names and their types",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively solves the core task of parsing CloudFormation templates and extracting resource names and types. The multi-format input handling is well-designed. However, production-readiness is compromised by absent error handling for edge cases and missing dependency documentation. The code would benefit from input validation, clearer error messages, and handling of malformed resource definitions."
#   },
#   {
#     "output": "# AWS Region Classifier\n\nHere's a Python function that classifies AWS regions:\n\n```python\ndef classify_aws_region(region_code: str) -> str:\n    \"\"\"\n    Classify an AWS region as standard commercial, GovCloud, or China region.\n    \n    Args:\n        region_code (str): AWS region code (e.g., 'us-east-1', 'us-gov-west-1', 'cn-north-1')\n    \n    Returns:\n        str: One of 'commercial', 'govcloud', or 'china'\n    \n    Raises:\n        ValueError: If the region code is invalid\n    \"\"\"\n    region_code = region_code.lower().strip()\n    \n    if not region_code:\n        raise ValueError(\"Region code cannot be empty\")\n    \n    # GovCloud regions\n    if region_code.startswith('us-gov-'):\n        return 'govcloud'\n    \n    # China regions\n    if region_code.startswith('cn-'):\n        return 'china'\n    \n    # Standard commercial regions\n    # Valid patterns: us-east-1, eu-west-1, ap-southeast-1, etc.\n    valid_commercial_patterns = [\n        'us-', 'eu-', 'ap-', 'ca-', 'sa-', 'me-', 'af-'\n    ]\n    \n    if any(region_code.startswith(pattern) for pattern in valid_commercial_patterns):\n        return 'commercial'\n    \n    raise ValueError(f\"Invalid or unrecognized AWS region code: {region_code}\")\n\n\n# Alternative version with explicit region lists\ndef classify_aws_region_strict(region_code: str) -> str:\n    \"\"\"\n    Strict classification using known AWS region lists.\n    \"\"\"\n    region_code = region_code.lower().strip()\n    \n    # GovCloud regions (as of 2024)\n    govcloud_regions = {\n        'us-gov-west-1',\n        'us-gov-east-1'\n    }\n    \n    # China regions (as of 2024)\n    china_regions = {\n        'cn-north-1',\n        'cn-northwest-1'\n    }\n    \n    # Commercial regions (representative list - not exhaustive)\n    commercial_regions = {\n        # US Regions\n        'us-east-1', 'us-east-2', 'us-west-1', 'us-west-2',\n        # Europe\n        'eu-west-1', 'eu-west-2', 'eu-west-3', 'eu-central-1', 'eu-north-1',\n        # Asia Pacific\n        'ap-south-1', 'ap-northeast-1', 'ap-northeast-2', 'ap-northeast-3',\n        'ap-southeast-1', 'ap-southeast-2',\n        # Canada\n        'ca-central-1',\n        # South America\n        'sa-east-1',\n        # Middle East\n        'me-south-1', 'me-central-1',\n        # Africa\n        'af-south-1'\n    }\n    \n    if region_code in govcloud_regions:\n        return 'govcloud'\n    elif region_code in china_regions:\n        return 'china'\n    elif region_code in commercial_regions:\n        return 'commercial'\n    else:\n        raise ValueError(f\"Unknown AWS region code: {region_code}\")\n```\n\n## Usage Examples\n\n```python\n# Test the function\ntest_regions = [\n    'us-east-1',          # Commercial\n    'us-west-2',          # Commercial\n    'eu-west-1',          # Commercial\n    'ap-southeast-1',     # Commercial\n    'us-gov-west-1',      # GovCloud\n    'us-gov-east-1',      # GovCloud\n    'cn-north-1',         # China\n    'cn-northwest-1',     # China\n]\n\nprint(\"=== Pattern-based Classification ===\")\nfor region in test_regions:\n    classification = classify_aws_region(region)\n    print",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS region code and returns whether it's a standard commercial region or a GovCloud/China region",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution addresses the core requirement with two reasonable approaches and good code practices. However, the pattern-based method sacrifices accuracy for flexibility, while the strict method requires ongoing maintenance. For production use, the pattern-based approach risks false positives, while the strict approach risks rejecting new valid regions. A hybrid approach using AWS's official region list API would be superior. The incomplete example code is a minor presentation issue."
#   }
# ]
